# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df.round(2)
vacation_df.head()
# Out:
#    City_ID          City Country  Max Temp Current Description   Lat     Lng  \
# 0        0         Kapaa      US     84.18     overcast clouds 22.08 -159.32
# 1        1      Qui Nhon      VN     84.47     overcast clouds 13.77  109.23
# 2       17  Puerto Ayora      EC     78.76       broken clouds -0.74  -90.35
# 3       21     Cattolica      IT     80.47     overcast clouds 43.96   12.74
# 4       23          Hilo      US     80.33          light rain 19.73 -155.09
#
#                             Hotel Name
# 0  Sheraton Kauai Coconut Beach Resort
# 1               Hoang Yen Canary Hotel
# 2            Finch Bay Galapagos Hotel
# 3                        Hotel Antares
# 4                  Hilo Hawaiian Hotel

# %%
vacation_df.isnull().sum().sum()
# Out:
# 0

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
#marker_layer = gmaps.marker_layer(locations, info_box_content='x')
fig.add_layer(marker_layer)
# 4b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
Us_cities_df = vacation_df.loc[ (vacation_df["Country"] == "US") ]
Us_cities_df
# Out:
#      City_ID            City Country  Max Temp   Current Description   Lat  \
# 0          0           Kapaa      US     84.18       overcast clouds 22.08
# 4         23            Hilo      US     80.33            light rain 19.73
# 14        55        Hamilton      US     80.78                  haze 39.18
# 22        89   Makakilo City      US     82.72         broken clouds 21.35
# 31       122       Watertown      US     77.52            few clouds 42.37
# 32       128          Bethel      US     75.07       overcast clouds 41.37
# 33       129        Amberley      US     80.10                  haze 39.20
# 56       211            Mayo      US     82.38       overcast clouds 38.89
# 59       224   Pacific Grove      US     84.16             clear sky 36.62
# 71       283  Virginia Beach      US     84.02         broken clouds 36.85
# 82       316          Palmer      US     76.55         broken clouds 42.16
# ...

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 

# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[(vacation_df['Hotel Name']=='Lovers Point Inn')]
vacation_end = vacation_start
vacation_stop1 = vacation_df.loc[(vacation_df['Hotel Name']=='Hilton Virginia Beach Oceanfront')]
vacation_stop2 = vacation_df.loc[(vacation_df['Hotel Name']=='Wedgewood Motel')] 
vacation_stop3 = vacation_df.loc[(vacation_df['Hotel Name']=='Hilton Garden Inn Indianapolis Downtown')] 
vacation_start
# Out:
#     City_ID           City Country  Max Temp Current Description   Lat  \
# 59      224  Pacific Grove      US     84.16           clear sky 36.62
#
#        Lng        Hotel Name
# 59 -121.92  Lovers Point Inn

# %%
vacation_stop1
# Out:
#     City_ID            City Country  Max Temp Current Description   Lat  \
# 71      283  Virginia Beach      US     84.02       broken clouds 36.85
#
#       Lng                        Hotel Name
# 71 -75.98  Hilton Virginia Beach Oceanfront

# %%
vacation_stop2
# Out:
#     City_ID    City Country  Max Temp Current Description   Lat    Lng  \
# 82      316  Palmer      US     76.55       broken clouds 42.16 -72.33
#
#          Hotel Name
# 82  Wedgewood Motel

# %%
vacation_stop3
# Out:
#      City_ID    City Country  Max Temp Current Description   Lat    Lng  \
# 184      676  Marion      US     80.92       broken clouds 39.77 -86.16
#
#                                   Hotel Name
# 184  Hilton Garden Inn Indianapolis Downtown

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.

start = tuple(map(tuple,vacation_start[['Lat','Lng']].to_numpy()))
end = start
stop1 = tuple(map(tuple,vacation_stop1[['Lat','Lng']].to_numpy()))
stop2 = tuple(map(tuple,vacation_stop2[['Lat','Lng']].to_numpy()))
stop3 = tuple(map(tuple,vacation_stop3[['Lat','Lng']].to_numpy()))

start  = start[0]
end = start
stop1 = stop1[0]
stop2 = stop2[0]
stop3 = stop3[0]

stop3[0]
# Out:
# 39.7684

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig1 = gmaps.figure()
vacay_route =\
     gmaps.directions_layer(start,end, waypoints=[stop1,stop2,stop3],travel_mode='DRIVING')
fig1.add_layer(vacay_route)
fig1
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID            City Country  Max Temp Current Description   Lat  \
# 0      224   Pacific Grove      US     84.16           clear sky 36.62
# 1      283  Virginia Beach      US     84.02       broken clouds 36.85
# 2      316          Palmer      US     76.55       broken clouds 42.16
# 3      676          Marion      US     80.92       broken clouds 39.77
#
#       Lng                               Hotel Name
# 0 -121.92                         Lovers Point Inn
# 1  -75.98         Hilton Virginia Beach Oceanfront
# 2  -72.33                          Wedgewood Motel
# 3  -86.16  Hilton Garden Inn Indianapolis Downtown

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig2 = gmaps.figure()
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
# 11b. Display the figure

fig2.add_layer(marker_layer)
fig2
# Out:
# Figure(layout=FigureLayout(height='420px'))
